# %%
#file= '2022090800_AET.nc'
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
import os
from mpl_toolkits.basemap import Basemap

# %%
ds=nc.Dataset('2022090800_Day.nc')
print(ds.variables.keys())

lat= ds.variables['latitude'][:]
lon= ds.variables['longitude'][:]
data=ds.variables['TMP_2maboveground'][0]
print(data)

lon0,lat0=np.meshgrid(lon,lat)
print(lat.shape,lon.shape,data.shape)
print(data.min())
print(data.max())
# Out:
# dict_keys(['latitude', 'longitude', 'time', 'PRES_surface', 'TMP_2maboveground', 'DPT_2maboveground', 'RH_2maboveground', 'UGRD_10maboveground', 'VGRD_10maboveground', 'APCP_surface'])
# [[298.74    298.75998 298.79    ... 300.72998 300.72998 300.72998]
#  [298.75998 298.75    298.75998 ... 300.77    300.77    300.75998]
#  [298.77    298.75    298.75    ... 300.81    300.8     300.78998]
#  ...
#  [294.06    294.12    294.19998 ... 295.94    296.00998 296.06   ]
#  [294.05    294.12    294.21    ... 296.03    296.07    296.11   ]
#  [294.06    294.13998 294.22998 ... 296.13    296.15    296.16   ]]
# (1850,) (1950,) (1850, 1950)
# 253.68
# 309.25998

# %%
clev=np.arange(data.min(),data.max(),2)
print(data.min())
print(data.max())
print(data.shape)
print(clev)
# Out:
# 253.68
# 309.25998
# (1850, 1950)
# [253.67999268 255.67999268 257.67999268 259.67999268 261.67999268
#  263.67999268 265.67999268 267.67999268 269.67999268 271.67999268
#  273.67999268 275.67999268 277.67999268 279.67999268 281.67999268
#  283.67999268 285.67999268 287.67999268 289.67999268 291.67999268
#  293.67999268 295.67999268 297.67999268 299.67999268 301.67999268
#  303.67999268 305.67999268 307.67999268]

# %%
m=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=40,llcrnrlon=40,urcrnrlon=110,resolution='l')
fig=plt.figure(figsize=(8,8),dpi=250)
m.drawcoastlines()
clev=np.arange(data.min(),data.max(),1)
parallels=np.arange(0,40,10)
m.drawparallels(parallels)
meridians=np.arange(55,110,20)
m.drawmeridians(meridians)
p=m.contourf(lon0,lat0,data,clev,cmap='jet')
cbar=m.colorbar(p,location='right')
plt.show()

# %%
m=Basemap(projection='cyl',llcrnrlat=0,urcrnrlat=40,llcrnrlon=50,urcrnrlon=102,resolution='l')
fig=plt.figure(figsize=(8,8),dpi=250)
m.drawcoastlines()
clev=np.arange(data.min(),data.max(),1)
parallels=np.arange(0,40,10)
m.drawparallels(parallels)
meridians=np.arange(55,110,20)
m.drawmeridians(meridians)
p=m.contourf(lon0,lat0,data,clev,cmap='jet')
cbar=m.colorbar(p,location='right')
plt.show()
